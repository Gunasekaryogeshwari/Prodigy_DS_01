# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Visualising the dataset provided**

# %%
data = pd.read_csv("/content/Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_79[1].csv")
data.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName  Unnamed: 5
# 0                        Aruba         NaN
# 1  Africa Eastern and Southern         NaN
# 2                  Afghanistan         NaN
# 3   Africa Western and Central         NaN
# 4                       Angola         NaN

# %%
print(data.head())
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName  Unnamed: 5
# 0                        Aruba         NaN
# 1  Africa Eastern and Southern         NaN
# 2                  Afghanistan         NaN
# 3   Africa Western and Central         NaN
# 4                       Angola         NaN

# %% [markdown]
# **Creation of a bargraph from the given dataset**

# %%
# Group data by IncomeGroup and sort by count
grouped_data = data.groupby('IncomeGroup').size().to_frame(name='Count').sort_values(by='Count', ascending=False)

# Define colors for each income group
colors = ['green', 'orange', 'blue','red']  # adjust as needed

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.hist(grouped_data['Count'], bins=[0, 10, 20, 30, 50], color=colors)  # Example bins for 4 colors

# Customize the plot
plt.xlabel('Income Group')
plt.ylabel('Count')
plt.title('Distribution of Countries by Income Group')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()

# Add labels to individual bars
for bar, count in zip(bars, grouped_data['Count']):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.2, int(count), ha='center', va='bottom')

# Display the plot
plt.show()

# %% [markdown]
# **Creation of the Histogram from the given dataset**

# %%
# Group data by IncomeGroup and sort by count
grouped_data = data.groupby('IncomeGroup').size().to_frame(name='Count').sort_values(by='Count', ascending=False)

# Create the histogram (using plt.hist)
plt.figure(figsize=(10, 6))
plt.hist(grouped_data['Count'], bins=len(colors), color='yellow')

# Customize the plot
plt.xlabel('Income Group')
plt.ylabel('Count')
plt.title('Distribution of Countries by Income Group')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()

# Display the plot
plt.show()
